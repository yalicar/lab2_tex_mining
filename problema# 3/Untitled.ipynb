# %%
import cv2
import numpy as np
import sys
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# impotar imagen
# =====================================
imagen = cv2.imread('sombrero.jpg')

# %%
# Funcion para convertir imagen a escala de grises
# =====================================
def grayscale(img):
    alto = img.shape[0]
    ancho = img.shape[1]
    gray = np.zeros((alto, ancho))
    for i in range(0, alto):
        for j in range(0, ancho):
            pixel = img[i,j]
            gray[i,j]=pixel.mean()
  #          gray[i,j][1]=pixel.mean()
   #         gray[i,j][2]=pixel.mean()
    
    return(gray.astype(int))
# Funcion para graficar imagen 2D en escala de grises en un plano 3D
def grafic_3D(img,a,b):
    gray = imgGray
    xx, yy = np.mgrid[0:img.shape[0], 0:img.shape[1]]
    # create the figure
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ax.plot_surface(xx, yy, img ,rstride=1, cstride=1, cmap=plt.cm.gray,
    linewidth=1)
    ax.view_init(a,b)
    # show it
    plt.show()

# %%
imgGray=grayscale(imagen)

# %%
grafic_3D(imgGray,90,0)

# %%
grafic_3D(imgGray,80,0)
